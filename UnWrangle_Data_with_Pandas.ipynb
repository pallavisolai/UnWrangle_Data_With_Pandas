# %% [markdown]
# ## Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv('Hotel_Job_Requirements.csv')

# %% [markdown]
# ## Shape of Data

# %%
df.shape
# Out:
# (20, 8)

# %% [markdown]
# ## First five rows of the data

# %%
df.head()
# Out:
#          area                                    job_title       company_name  \
# 0  Hotel Jobs                   Operations Manager @ Hotel         ABC Groups
# 1  Hotel Jobs            Operation Manager (Resorts/Hotel)    The Lake Resort
# 2  Hotel Jobs     Hotel Manager Required in Malta (europe)   Horizon services
# 3  Hotel Jobs  Hotel Manager (germany) - No IELTS Required  Dreamland Pvt Ltd
# 4  Hotel Jobs                         Front Office Manager      Hotel Riptide
#
#      experience                        salary         location_list  \
# 0   3 - 6 years  ? 32,50,000 - 45,00,000 P.A.       Pune, Bengaluru
# 1  5 - ?6 years  ? 25,00,000 - 40,00,000 P.A.               Gurgaon
# 2   5 - 7 years                 Not Disclosed  United Kingdom (U.K)
# 3      0 - 4 yr  ? 25,00,000 - 40,00,000 P.A.               Germany
# 4  0 - 2 years!                 Not Disclosed                  Pune
#
#                                                 desc  \
# 0  Job descriptionoversee the entire operations o...
# 1  Job Description: \r\r\n Maintaining positive p...
# 2  Job descriptionRecruiting, training and superv...
# 3  Job descriptionHotel managers are responsible ...
# 4  Job descriptionDeliver strong functional exper...
#
#                                           key_skills
# 0  ['back office management', 'Operations Managem...
# 1  ['Operations management', 'Hospitality', 'Publ...
# 2  ['hotel manager', 'hospitality manager', 'hote...
# 3  ['assistant restaurant manager', 'hotel genera...
# 4  ['Leadership', 'Kitchen Manager', 'Hotel Manag...

# %% [markdown]
# ## Basic summary of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
# area             20 non-null object
# job_title        20 non-null object
# company_name     20 non-null object
# experience       20 non-null object
# salary           20 non-null object
# location_list    20 non-null object
# desc             20 non-null object
# key_skills       20 non-null object
# dtypes: object(8)
# memory usage: 1.3+ KB

# %% [markdown]
# ## Number of unique values in each column

# %%
for i in df.columns:
    print(i, " : ", df[i].nunique())
# Out:
# area  :  1
# job_title  :  15
# company_name  :  14
# experience  :  16
# salary  :  5
# location_list  :  20
# desc  :  20
# key_skills  :  19

# %% [markdown]
# ## Lowercase
# Converting characters to lowercase

# %%
df = df.apply(lambda x: x.astype(str).str.lower())
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#          area                                    job_title       company_name  \
# 0  hotel jobs                   operations manager @ hotel         abc groups
# 1  hotel jobs            operation manager (resorts/hotel)    the lake resort
# 2  hotel jobs     hotel manager required in malta (europe)   horizon services
# 3  hotel jobs  hotel manager (germany) - no ielts required  dreamland pvt ltd
# 4  hotel jobs                         front office manager      hotel riptide
#
#      experience                        salary         location_list  \
# 0   3 - 6 years  ? 32,50,000 - 45,00,000 p.a.       pune, bengaluru
# 1  5 - ?6 years  ? 25,00,000 - 40,00,000 p.a.               gurgaon
# 2   5 - 7 years                 not disclosed  united kingdom (u.k)
# 3      0 - 4 yr  ? 25,00,000 - 40,00,000 p.a.               germany
# 4  0 - 2 years!                 not disclosed                  pune
#
#                                                 desc  \
# 0  job descriptionoversee the entire operations o...
# 1  job description: \r\r\n maintaining positive p...
# 2  job descriptionrecruiting, training and superv...
# 3  job descriptionhotel managers are responsible ...
# 4  job descriptiondeliver strong functional exper...
#
#                                           key_skills
# 0  ['back office management', 'operations managem...
# 1  ['operations management', 'hospitality', 'publ...
# 2  ['hotel manager', 'hospitality manager', 'hote...
# 3  ['assistant restaurant manager', 'hotel genera...
# 4  ['leadership', 'kitchen manager', 'hotel manag...

# %%
for i in df.columns:
    print(i, " : ", df[i].nunique())
# Out:
# area  :  1
# job_title  :  15
# company_name  :  14
# experience  :  16
# salary  :  5
# location_list  :  20
# desc  :  19
# key_skills  :  19

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Column job_title

# %%
df[['job_title']]
# Out:
#                                             job_title
# 0                          operations manager @ hotel
# 1                   operation manager (resorts/hotel)
# 2            hotel manager required in malta (europe)
# 3         hotel manager (germany) - no ielts required
# 4                                front office manager
# 5                                       hotel manager
# 6                           front office duty manager
# 7                                       hotel manager
# 8                                       hotel manager
# 9                                       hotel manager
# 10            banquet / sales coordinator / executive
# 11                                      hotel manager
# 12      front office associate ( from hotel industry)
# 13                                     hotel manager,
# 14                                      hotel manager
# 15                               hotel staff required
# 16                   f&b captain / restaurant manager
# 17                                             waiter
# 18  hotel managers - apply under pr visa for canad...
# 19                            f & b associate steward

# %%
df['job_title_clean'] = df['job_title'].str.replace(r"[^a-zA-Z\d\_\&]+", " ")

df[['job_title_clean']]
# Out:
#                                       job_title_clean
# 0                            operations manager hotel
# 1                    operation manager resorts hotel
# 2             hotel manager required in malta europe
# 3             hotel manager germany no ielts required
# 4                                front office manager
# 5                                       hotel manager
# 6                           front office duty manager
# 7                                       hotel manager
# 8                                       hotel manager
# 9                                       hotel manager
# 10                banquet sales coordinator executive
# 11                                      hotel manager
# 12        front office associate from hotel industry
# 13                                     hotel manager
# 14                                      hotel manager
# 15                               hotel staff required
# 16                     f&b captain restaurant manager
# 17                                             waiter
# 18  hotel managers apply under pr visa for canada ...
# 19                            f & b associate steward

# %%
stopwords = ['the', 'and', 'or', 'in', 'for', 'of', 'from', 'apply', 'pr', 'to', 'pvt', 'ltd', 'under', 'llp']

# %%
for i in stopwords :
    df['job_title_clean'] = df['job_title_clean'].replace(to_replace=r'\b%s\b'%i, value=" ",regex=True)

# %%
df[['job_title_clean']]
# Out:
#                                       job_title_clean
# 0                            operations manager hotel
# 1                    operation manager resorts hotel
# 2              hotel manager required   malta europe
# 3             hotel manager germany no ielts required
# 4                                front office manager
# 5                                       hotel manager
# 6                           front office duty manager
# 7                                       hotel manager
# 8                                       hotel manager
# 9                                       hotel manager
# 10                banquet sales coordinator executive
# 11                                      hotel manager
# 12           front office associate   hotel industry
# 13                                     hotel manager
# 14                                      hotel manager
# 15                               hotel staff required
# 16                     f&b captain restaurant manager
# 17                                             waiter
# 18  hotel managers       visa   canada australia h...
# 19                            f & b associate steward

# %% [markdown]
# ### Column company_name

# %%
df[['company_name']]
# Out:
#                 company_name
# 0                 abc groups
# 1            the lake resort
# 2           horizon services
# 3          dreamland pvt ltd
# 4              hotel riptide
# 5                  xyz hotel
# 6             paradise hotel
# 7   random solutions pvt ltd
# 8              yes solutions
# 9      oakbranch hotel chain
# 10                hotel lily
# 11                deep group
# 12           the lake resort
# 13            orange orchid
# 14          horizon services
# 15          horizon services
# 16             hotel riptide
# 17            paradise hotel
# 18  immigration services llp
# 19     oakbranch hotel chain

# %%
df['company_name_clean'] = df['company_name'].str.replace(r"[^a-zA-Z\d\_\&]+", " ")

df[['company_name_clean']]
# Out:
#           company_name_clean
# 0                 abc groups
# 1            the lake resort
# 2           horizon services
# 3          dreamland pvt ltd
# 4              hotel riptide
# 5                  xyz hotel
# 6             paradise hotel
# 7   random solutions pvt ltd
# 8              yes solutions
# 9      oakbranch hotel chain
# 10                hotel lily
# 11                deep group
# 12           the lake resort
# 13            orange orchid
# 14          horizon services
# 15          horizon services
# 16             hotel riptide
# 17            paradise hotel
# 18  immigration services llp
# 19     oakbranch hotel chain

# %%
for i in stopwords :
    df['company_name_clean'] = df['company_name_clean'].replace(to_replace=r'\b%s\b'%i, value=" ",regex=True)

# %%
df[['company_name_clean']]
# Out:
#         company_name_clean
# 0               abc groups
# 1              lake resort
# 2         horizon services
# 3            dreamland
# 4            hotel riptide
# 5                xyz hotel
# 6           paradise hotel
# 7     random solutions
# 8            yes solutions
# 9    oakbranch hotel chain
# 10              hotel lily
# 11              deep group
# 12             lake resort
# 13          orange orchid
# 14        horizon services
# 15        horizon services
# 16           hotel riptide
# 17          paradise hotel
# 18  immigration services
# 19   oakbranch hotel chain

# %% [markdown]
# ### column experience

# %%
df[['experience']]
# Out:
#       experience
# 0    3 - 6 years
# 1   5 - ?6 years
# 2    5 - 7 years
# 3       0 - 4 yr
# 4   0 - 2 years!
# 5      - 1 years
# 6    2 - 4 years
# 7    3 - 5 years
# 8    2 - 5 years
# 9    5 - 8 years
# 10    1- 5 years
# 11    5 -8 years
# 12   0 - 2 years
# 13  5 - 10 years
# 14  5 - 10 years
# 15   1 - 6 years
# 16   1 - 6 years
# 17   0 - 2 years
# 18  6 - 11 years
# 19   1 - 6 years

# %%
df['experience_clean'] = df['experience'].str.replace(r"[^\d\ \-]+", " ")

df[['experience_clean']]
# Out:
#    experience_clean
# 0           3 - 6
# 1          5 -  6
# 2           5 - 7
# 3           0 - 4
# 4           0 - 2
# 5             - 1
# 6           2 - 4
# 7           3 - 5
# 8           2 - 5
# 9           5 - 8
# 10           1- 5
# 11           5 -8
# 12          0 - 2
# 13         5 - 10
# 14         5 - 10
# 15          1 - 6
# 16          1 - 6
# 17          0 - 2
# 18         6 - 11
# 19          1 - 6

# %% [markdown]
# ### column salary

# %%
df[['salary']]
# Out:
#                           salary
# 0   ? 32,50,000 - 45,00,000 p.a.
# 1   ? 25,00,000 - 40,00,000 p.a.
# 2                  not disclosed
# 3   ? 25,00,000 - 40,00,000 p.a.
# 4                  not disclosed
# 5                  not disclosed
# 6     ? 2,25,000 - 3,00,000 p.a.
# 7                  not disclosed
# 8                  not disclosed
# 9         $ 55,000 - 75,000 p.a.
# 10                 not disclosed
# 11                 not disclosed
# 12                 not disclosed
# 13    ? 2,25,000 - 3,00,000 p.a.
# 14                 not disclosed
# 15  ? 25,00,000 - 40,00,000 p.a.
# 16                 not disclosed
# 17  ? 32,50,000 - 45,00,000 p.a.
# 18                 not disclosed
# 19                 not disclosed

# %%
df['salary_clean'] = df['salary'].str.replace(r"[^\d\ \-]+", "")

df[['salary_clean']]
# Out:
#            salary_clean
# 0    3250000 - 4500000
# 1    2500000 - 4000000
# 2
# 3    2500000 - 4000000
# 4
# 5
# 6      225000 - 300000
# 7
# 8
# 9        55000 - 75000
# 10
# 11
# 12
# 13     225000 - 300000
# 14
# 15   2500000 - 4000000
# 16
# 17   3250000 - 4500000
# 18
# 19

# %% [markdown]
# ### Column location

# %%
df[['location_list']]
# Out:
#               location_list
# 0           pune, bengaluru
# 1                   gurgaon
# 2      united kingdom (u.k)
# 3                   germany
# 4                      pune
# 5               kanyakumari
# 6                    mumbai
# 7   thane, kalyan-dombivali
# 8                  guwahati
# 9                 pan india
# 10                      goa
# 11                hazaribag
# 12              navi mumbai
# 13                  lucknow
# 14                   canada
# 15         malaysia, canada
# 16          pune( panshet )
# 17                 kottayam
# 18        hong kong, canada
# 19                   panjim

# %%
df['location_list_clean'] = df['location_list'].str.replace(r"[^a-zA-Z\_\,]+", " ")

df[['location_list_clean']]
# Out:
#         location_list_clean
# 0           pune, bengaluru
# 1                   gurgaon
# 2       united kingdom u k
# 3                   germany
# 4                      pune
# 5               kanyakumari
# 6                    mumbai
# 7   thane, kalyan dombivali
# 8                  guwahati
# 9                 pan india
# 10                      goa
# 11                hazaribag
# 12              navi mumbai
# 13                  lucknow
# 14                   canada
# 15         malaysia, canada
# 16            pune panshet
# 17                 kottayam
# 18        hong kong, canada
# 19                   panjim

# %% [markdown]
# ### Column desc

# %%
df['desc'][1]
# Out:
# 'job description: \r\r\n maintaining positive public relations and pleasant attitude with all guests and associates \r\r\n manage the administrative staff and train new hires on office policies and procedures.\r\n coordinate and manage communication between guest and staff and follow up to ensure complete service recovery. \r\r\ngood analytical ability and communication skills,  proficient in ms office.'

# %%
df['desc_clean'] = df['desc'].str.replace(r"[^a-zA-Z\.\,]+", " ")
df['desc_clean'] = df['desc_clean'].str.replace("job description", "")

df[['desc_clean']]
# Out:
#                                            desc_clean
# 0   oversee the entire operations of a lodging est...
# 1    maintaining positive public relations and ple...
# 2   recruiting, training and supervising staff.man...
# 3   hotel managers are responsible for managing em...
# 4   deliver strong functional expertise,creativity...
# 5    hiring hotel manager for deluxe hotel in kany...
# 6    . greets the vip guests of the hotel. as dire...
# 7   we required urgently hotel or order manager fo...
# 8                       job profile restaurant manger
# 9    in charge of the hotel operations of the unit...
# 10   to supervise all phases of all type of banque...
# 11                    should trained in culinary arts
# 12   the job requires extensive communications wit...
# 13  required hotel manager to take care of overall...
# 14  recruiting, training and supervising staff.man...
# 15               supervisor manger for different dept
# 16  must be experienced in multi cuisine restauran...
# 17   the candidate should be well versed with serv...
# 18  hotel managers are in shortage in australia ca...
# 19  responsible to serve food beverage to guests i...

# %%
df['desc_clean'][1]
# Out:
# ' maintaining positive public relations and pleasant attitude with all guests and associates manage the administrative staff and train new hires on office policies and procedures. coordinate and manage communication between guest and staff and follow up to ensure complete service recovery. good analytical ability and communication skills, proficient in ms office.'

# %% [markdown]
# ### column key_skills

# %%
df[['key_skills']]
# Out:
#                                            key_skills
# 0   ['back office management', 'operations managem...
# 1   ['operations management', 'hospitality', 'publ...
# 2   ['hotel manager', 'hospitality manager', 'hote...
# 3   ['assistant restaurant manager', 'hotel genera...
# 4   ['leadership', 'kitchen manager', 'hotel manag...
# 5                            ['interpersonal skills']
# 6   ['front office staff', 'public relations', 'fr...
# 7   ['hotel manager', 'restaurant manager', 'order...
# 8   ['hotel manager restaurant manager company pro...
# 9   ['incharge', 'sales', 'performance management'...
# 10  ['supervisor', 'banquet sales coordinator', 's...
# 11  ['cost effeciency', 'hotel management', 'budge...
# 12  ['front desk', 'receptionist', 'front office',...
# 13                               ['hotel management']
# 14  ['hotel manager', 'hospitality manager', 'hote...
# 15  ['store keeping', 'front office', 'kitchen', '...
# 16  ['restaurant', 'bar', 'restaurant manager', 'f...
# 17               ['hospitality management', 'waiter']
# 18  ['hotel supervisor', 'food & beverage manager'...
# 19  ['guest satisfaction', 'hotel management', 'f&...

# %%
df['key_skills_clean'] = df['key_skills'].str.replace(r"[^a-zA-Z\ \,]+", " ")
df[['key_skills_clean']]
# Out:
#                                      key_skills_clean
# 0    back office management ,  operations management
# 1    operations management ,  hospitality ,  publi...
# 2    hotel manager ,  hospitality manager ,  hotel...
# 3    assistant restaurant manager ,  hotel general...
# 4    leadership ,  kitchen manager ,  hotel manage...
# 5                               interpersonal skills
# 6    front office staff ,  public relations ,  fro...
# 7    hotel manager ,  restaurant manager ,  order ...
# 8    hotel manager restaurant manager company prof...
# 9    incharge ,  sales ,  performance management ,...
# 10   supervisor ,  banquet sales coordinator ,  se...
# 11   cost effeciency ,  hotel management ,  budget...
# 12   front desk ,  receptionist ,  front office , ...
# 13                                  hotel management
# 14   hotel manager ,  hospitality manager ,  hotel...
# 15   store keeping ,  front office ,  kitchen ,  a...
# 16   restaurant ,  bar ,  restaurant manager ,  f ...
# 17                  hospitality management ,  waiter
# 18   hotel supervisor ,  food   beverage manager ,...
# 19   guest satisfaction ,  hotel management ,  f b...

# %% [markdown]
# ## Creation of New Columns

# %% [markdown]
# ### Number of Years of Experience

# %%
df[['minimum_year_exp', 'maximum_year_exp']] = df['experience_clean'].str.split('-', expand=True)
df['minimum_year_exp'] = df['minimum_year_exp'].str.strip().replace('', 0).astype('int64')
df['maximum_year_exp'] = df['maximum_year_exp'].str.strip().replace('', 0).astype('int64')

# %%
df['number_of_years_exp'] = df['maximum_year_exp'] - df['minimum_year_exp']

df[['minimum_year_exp', 'maximum_year_exp', 'number_of_years_exp']]
# Out:
#     minimum_year_exp  maximum_year_exp  number_of_years_exp
# 0                  3                 6                    3
# 1                  5                 6                    1
# 2                  5                 7                    2
# 3                  0                 4                    4
# 4                  0                 2                    2
# 5                  0                 1                    1
# 6                  2                 4                    2
# 7                  3                 5                    2
# 8                  2                 5                    3
# 9                  5                 8                    3
# 10                 1                 5                    4
# 11                 5                 8                    3
# 12                 0                 2                    2
# 13                 5                10                    5
# 14                 5                10                    5
# 15                 1                 6                    5
# 16                 1                 6                    5
# 17                 0                 2                    2
# 18                 6                11                    5
# 19                 1                 6                    5

# %% [markdown]
# ### Average Salary

# %%
df[['minimum_salary', 'maximum_salary']] = df['salary_clean'].str.split('-', expand=True)
df['minimum_salary'] = df['minimum_salary'].str.strip().replace({'': 0}).astype('float64')
df['maximum_salary'] = df['maximum_salary'].str.strip().replace({'': 0}).astype('float64')

df['average_salary'] = (df['maximum_salary'] - df['minimum_salary'])/2

df[['maximum_salary', 'maximum_salary', 'average_salary']]
# Out:
#     maximum_salary  maximum_salary  average_salary
# 0        4500000.0       4500000.0        625000.0
# 1        4000000.0       4000000.0        750000.0
# 2              NaN             NaN             NaN
# 3        4000000.0       4000000.0        750000.0
# 4              NaN             NaN             NaN
# 5              NaN             NaN             NaN
# 6         300000.0        300000.0         37500.0
# 7              NaN             NaN             NaN
# 8              NaN             NaN             NaN
# 9          75000.0         75000.0         10000.0
# 10             NaN             NaN             NaN
# 11             NaN             NaN             NaN
# 12             NaN             NaN             NaN
# 13        300000.0        300000.0         37500.0
# 14             NaN             NaN             NaN
# 15       4000000.0       4000000.0        750000.0
# 16             NaN             NaN             NaN
# 17       4500000.0       4500000.0        625000.0
# 18             NaN             NaN             NaN
# 19             NaN             NaN             NaN

# %% [markdown]
# ### Number of Key Skills

# %%
df['number_of_key_skills'] = df['key_skills_clean'].str.split(',').str.len()

df[['key_skills_clean', 'number_of_key_skills']]
# Out:
#                                      key_skills_clean  number_of_key_skills
# 0    back office management ,  operations management                      2
# 1    operations management ,  hospitality ,  publi...                    10
# 2    hotel manager ,  hospitality manager ,  hotel...                     7
# 3    assistant restaurant manager ,  hotel general...                    11
# 4    leadership ,  kitchen manager ,  hotel manage...                     5
# 5                               interpersonal skills                      1
# 6    front office staff ,  public relations ,  fro...                     8
# 7    hotel manager ,  restaurant manager ,  order ...                     5
# 8    hotel manager restaurant manager company prof...                     1
# 9    incharge ,  sales ,  performance management ,...                     9
# 10   supervisor ,  banquet sales coordinator ,  se...                     5
# 11   cost effeciency ,  hotel management ,  budget...                     8
# 12   front desk ,  receptionist ,  front office , ...                     5
# 13                                  hotel management                      1
# 14   hotel manager ,  hospitality manager ,  hotel...                     7
# 15   store keeping ,  front office ,  kitchen ,  a...                     6
# 16   restaurant ,  bar ,  restaurant manager ,  f ...                     6
# 17                  hospitality management ,  waiter                      2
# 18   hotel supervisor ,  food   beverage manager ,...                    14
# 19   guest satisfaction ,  hotel management ,  f b...                     3
